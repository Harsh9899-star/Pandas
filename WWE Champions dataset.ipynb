# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
wwe=pd.read_csv("C:/Users/USER/Downloads/archive (2)/data.csv")

# %%
wwe
# Out:
#                  name  reign  days       date              event  \
# 0        Buddy Rogers      1    36  11-Apr-63         House show
# 1    Bruno Sammartino      1  2803  17-May-63         House show
# 2         Ivan Koloff      1    21  18-Jan-71         House show
# 3       Pedro Morales      1  1027   8-Feb-71         House show
# 4        Stan Stasiak      1     9   1-Dec-73         House show
# ..                ...    ...   ...        ...                ...
# 407       Becky Lynch      3    41   8-Apr-19    WrestleMania 35
# 408   Charlotte Flair      4     0  19-May-19  Money in the Bank
# 409            Bayley      1   140  19-May-19  Money in the Bank
# 410   Charlotte Flair      5     5   6-Oct-19     Hell in a Cell
# 411            Bayley      2   247  11-Oct-19          SmackDown
#
#                 location                           link  \
# 0       Washington, D.C.  /wiki/Buddy_Rogers_(wrestler)
# 1           New York, NY         /wiki/Bruno_Sammartino
# ...

# %%
wwe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            412 non-null    object
#  1   reign           412 non-null    int64
#  2   days            412 non-null    int64
#  3   date            412 non-null    object
#  4   event           412 non-null    object
#  5   location        412 non-null    object
#  6   link            412 non-null    object
#  7   belt            412 non-null    object
#  8   date_of_birth   409 non-null    object
#  9   date_of_death   57 non-null     object
#  10  cause_of_death  27 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 35.5+ KB

# %%
wwe.isnull().sum()
# Out:
# name                0
# reign               0
# days                0
# date                0
# event               0
# location            0
# link                0
# belt                0
# date_of_birth       3
# date_of_death     355
# cause_of_death    385
# dtype: int64

# %%
wwe.groupby(['name'])['date_of_death'].unique()
# Out:
# name
# AJ Styles                 [nan]
# Alberto Del Rio           [nan]
# Alexa Bliss               [nan]
# Alundra Blayze            [nan]
# Andrade                   [nan]
#                        ...
# Wahoo McDaniel      [4/18/2002]
# Wendi Richter             [nan]
# Yokozuna           [10/23/2000]
# Yukiko Tomoe              [nan]
# Zack Ryder                [nan]
# Name: date_of_death, Length: 175, dtype: object

# %% [markdown]
# ## These all wrestlers are alive where the value of column "date of death" is np.nan

# %% [markdown]
# # Reign is defined as number of times a particular wrestler hold a title

# %%
x=wwe.groupby(['reign'])['name'].agg(['max'])
x.sort_values(by='reign',ascending=False)
# Out:
#                   max
# reign
# 13          John Cena
# 12          John Cena
# 11          John Cena
# 10          John Cena
# 9            Triple H
# 8            Triple H
# 7       Trish Stratus
# 6       Trish Stratus
# 5      Wahoo McDaniel
# 4      Wahoo McDaniel
# 3      Wahoo McDaniel
# 2            Yokozuna
# 1          Zack Ryder

# %%
g=wwe[wwe['name']=='John Cena']
g
# Out:
#           name  reign  days       date                event  \
# 78   John Cena      1   280   3-Apr-05      WrestleMania 21
# 80   John Cena      2   133  29-Jan-06         Royal Rumble
# 83   John Cena      3   380  17-Sep-06           Unforgiven
# 95   John Cena      4    21  13-Sep-09       Breaking Point
# 97   John Cena      5    49  25-Oct-09      Bragging Rights
# 99   John Cena      6     0  21-Feb-10  Elimination Chamber
# 101  John Cena      7    84  28-Mar-10    WrestleMania XXVI
# 105  John Cena      8    77   1-May-11        Extreme Rules
# 108  John Cena      9    20  25-Jul-11                  Raw
# 111  John Cena     10    14  18-Sep-11   Night of Champions
# 115  John Cena     11   133   7-Apr-13      WrestleMania 29
# 121  John Cena     12    49  29-Jun-14    Money in the Bank
# 132  John Cena     13    14  29-Jan-17         Royal Rumble
# 325  John Cena      1   114  14-Mar-04      WrestleMania XX
# 327  John Cena      2     2   3-Oct-04             No Mercy
# ...

# %%
g['belt'].value_counts()
# Out:
# WWE Championship                  13
# WWE United States Championship     5
# Name: belt, dtype: int64

# %% [markdown]
# ### John Cena has won the wwe championship 13 times. His best record to hold the title is 380 days when he won the wwe championship 3rd time at event "unforgiven" and 5 times wwe united states champion

# %%
wwe['belt'].unique()
# Out:
# array(['WWE Championship', "WWE Women's Championship",
#        "WWE Raw Women's Championship", 'WWE United States Championship',
#        "WWE SmackDown Women's Championship"], dtype=object)

# %%
f=wwe[wwe['name']=='The Undertaker']
f
# Out:
#               name  reign  days       date            event         location  \
# 19  The Undertaker      1     6  27-Nov-91  Survivor Series      Detroit, MI
# 37  The Undertaker      2   133  23-Mar-97  WrestleMania 13     Rosemont, IL
# 49  The Undertaker      3    36  23-May-99    Over the Edge  Kansas City, MO
# 68  The Undertaker      4    63  19-May-02     Judgment Day    Nashville, TN
#
#                     link              belt date_of_birth date_of_death  \
# 19  /wiki/The_Undertaker  WWE Championship     3/24/1965           NaN
# 37  /wiki/The_Undertaker  WWE Championship     3/24/1965           NaN
# 49  /wiki/The_Undertaker  WWE Championship     3/24/1965           NaN
# 68  /wiki/The_Undertaker  WWE Championship     3/24/1965           NaN
#
#    cause_of_death
# 19            NaN
# 37            NaN
# 49            NaN
# 68            NaN

# %%
wwe['name'].unique()
# Out:
# array(['Buddy Rogers', 'Bruno Sammartino', 'Ivan Koloff', 'Pedro Morales',
#        'Stan Stasiak', 'Superstar Billy Graham', 'Bob Backlund',
#        'Antonio Inoki', 'The Iron Sheik', 'Hulk Hogan', 'André the Giant',
#        'Ted DiBiase', 'Randy Savage', 'The Ultimate Warrior',
#        'Sgt. Slaughter', 'The Undertaker', 'Ric Flair', 'Bret Hart',
#        'Yokozuna', 'Diesel', 'Shawn Michaels', 'Sycho Sid',
#        'Stone Cold Steve Austin', 'Kane', 'The Rock', 'Mankind',
#        'Triple H', 'Vince McMahon', 'Big Show', 'Kurt Angle',
#        'Chris Jericho', 'Hollywood Hulk Hogan', 'Brock Lesnar',
#        'Eddie Guerrero', 'John Bradshaw Layfield', 'John Cena', 'Edge',
#        'Rob Van Dam', 'Randy Orton', 'Jeff Hardy', 'Batista', 'Sheamus',
#        'The Miz', 'CM Punk', 'Rey Mysterio', 'Alberto Del Rio',
#        'Daniel Bryan', 'Seth Rollins', 'Roman Reigns', 'Dean Ambrose',
#        'AJ Styles', 'Bray Wyatt', 'Jinder Mahal', 'Kofi Kingston',
# ...

# %%
wwe[wwe['reign']==9]
# Out:
#             name  reign  days       date            event     location  \
# 108    John Cena      9    20  25-Jul-11              Raw  Hampton, VA
# 127     Triple H      9    70  24-Jan-16     Royal Rumble  Orlando, FL
# 134  Randy Orton      9    49   2-Apr-17  WrestleMania 33  Orlando, FL
#
#                   link              belt date_of_birth date_of_death  \
# 108    /wiki/John_Cena  WWE Championship     4/23/1977           NaN
# 127     /wiki/Triple_H  WWE Championship     7/27/1969           NaN
# 134  /wiki/Randy_Orton  WWE Championship      4/1/1980           NaN
#
#     cause_of_death
# 108            NaN
# 127            NaN
# 134            NaN

# %% [markdown]
# ## Triple H and Randy ortan has won the wwe championship 9 times

# %%
wwe[wwe['reign']==8]
# Out:
#             name  reign  days       date           event     location  \
# 91      Triple H      8    70  15-Feb-09      No Way Out  Seattle, WA
# 105    John Cena      8    77   1-May-11   Extreme Rules    Tampa, FL
# 114     The Rock      8    70  27-Jan-13    Royal Rumble  Phoenix, AZ
# 119  Randy Orton      8   161  27-Oct-13  Hell in a Cell    Miami, FL
#
#                      link              belt date_of_birth date_of_death  \
# 91         /wiki/Triple_H  WWE Championship     7/27/1969           NaN
# 105       /wiki/John_Cena  WWE Championship     4/23/1977           NaN
# 114  /wiki/Dwayne_Johnson  WWE Championship      5/2/1972           NaN
# 119     /wiki/Randy_Orton  WWE Championship      4/1/1980           NaN
#
#     cause_of_death
# 91             NaN
# 105            NaN
# 114            NaN
# 119            NaN

# %% [markdown]
# ## The Rock has won it 8 times after that john cena took over from him in wrestle mania

# %%
wwe[wwe['reign']==7]
# Out:
#               name  reign  days       date              event  \
# 69        The Rock      7    35  21-Jul-02          Vengeance
# 87        Triple H      7   210  27-Apr-08           Backlash
# 101      John Cena      7    84  28-Mar-10  WrestleMania XXVI
# 117    Randy Orton      7    28  18-Aug-13         SummerSlam
# 192  Trish Stratus      7     1  17-Sep-06         Unforgiven
#
#             location                  link                      belt  \
# 69       Detroit, MI  /wiki/Dwayne_Johnson          WWE Championship
# 87     Baltimore, MD        /wiki/Triple_H          WWE Championship
# 101     Glendale, AZ       /wiki/John_Cena          WWE Championship
# 117  Los Angeles, CA     /wiki/Randy_Orton          WWE Championship
# 192      Toronto, ON   /wiki/Trish_Stratus  WWE Women's Championship
#
#     date_of_birth date_of_death cause_of_death
# 69       5/2/1972           NaN            NaN
# 87      7/27/1969           NaN            NaN
# ...

# %% [markdown]
# ## Trish startus has won the wwe women's championship 7 times

# %%
wwe[wwe['reign']==6]
# Out:
#                         name  reign  days       date                  event  \
# 61                  The Rock      6    35  25-Feb-01             No Way Out
# 64   Stone Cold Steve Austin      6    62   8-Oct-01                    Raw
# 67      Hollywood Hulk Hogan      6    28  21-Apr-02               Backlash
# 85                  Triple H      6     0   7-Oct-07               No Mercy
# 99                 John Cena      6     0  21-Feb-10    Elimination Chamber
# 103              Randy Orton      6    64  19-Sep-10     Night of Champions
# 189            Trish Stratus      6   448   9-Jan-05  New Year's Revolution
#
#              location                           link  \
# 61      Las Vegas, NV           /wiki/Dwayne_Johnson
# 64   Indianapolis, IN  /wiki/Stone_Cold_Steve_Austin
# 67    Kansas City, MO     /wiki/Hollywood_Hulk_Hogan
# 85       Rosemont, IL                 /wiki/Triple_H
# 99      St. Louis, MO                /wiki/John_Cena
# ...

# %% [markdown]
# ## Hulk Hogan and stone cold steve austin has won the wwe championship 6 time

# %%
r=wwe[wwe['reign']==5]
r
# Out:
#                         name  reign  days       date  \
# 26                Hulk Hogan      5    70   4-Apr-93
# 38                 Bret Hart      5    98   3-Aug-97
# 59                  The Rock      5   119  25-Jun-00
# 62   Stone Cold Steve Austin      5   175   1-Apr-01
# 66                  Triple H      5    35  17-Mar-02
# 96               Randy Orton      5    21   4-Oct-09
# 97                 John Cena      5    49  25-Oct-09
# 139             Brock Lesnar      5   173   4-Oct-19
# 149      The Fabulous Moolah      5  2113  10-Oct-78
# 187            Trish Stratus      5   176  13-Jun-04
# 204             Mickie James      5    23  31-Jan-10
# 243                Ric Flair      5    64  24-Nov-80
# 256           Wahoo McDaniel      5   167   7-Oct-84
# 282                Ric Flair      5   141   7-Jul-96
# 292                Lex Luger      5     3  10-Aug-98
# 339             Chris Benoit      5   222  10-Oct-06
# 346                Bret Hart      5     7  17-May-10
# ...

# %%
a=r.iloc[np.where(r['belt']=='WWE Championship')]
a
# Out:
#                         name  reign  days       date  \
# 26                Hulk Hogan      5    70   4-Apr-93
# 38                 Bret Hart      5    98   3-Aug-97
# 59                  The Rock      5   119  25-Jun-00
# 62   Stone Cold Steve Austin      5   175   1-Apr-01
# 66                  Triple H      5    35  17-Mar-02
# 96               Randy Orton      5    21   4-Oct-09
# 97                 John Cena      5    49  25-Oct-09
# 139             Brock Lesnar      5   173   4-Oct-19
#
#                            event             location  \
# 26               WrestleMania IX        Las Vegas, NV
# 38                    SummerSlam  East Rutherford, NJ
# 59              King of the Ring           Boston, MA
# 62          WrestleMania X-Seven          Houston, TX
# 66               WrestleMania X8  Toronto, ON, Canada
# 96                Hell in a Cell           Newark, NJ
# 97               Bragging Rights       Pittsburgh, PA
# ...

# %% [markdown]
# ## Brock lesner and Bret hart has won the wwe champioship 5 times

# %%
r.iloc[np.where(r['belt']=='WWE United States Championship')]
# Out:
#                name  reign  days       date               event  \
# 243       Ric Flair      5    64  24-Nov-80          House show
# 256  Wahoo McDaniel      5   167   7-Oct-84          House show
# 282       Ric Flair      5   141   7-Jul-96   Bash at the Beach
# 292       Lex Luger      5     3  10-Aug-98               Nitro
# 339    Chris Benoit      5   222  10-Oct-06          SmackDown!
# 346       Bret Hart      5     7  17-May-10                 Raw
# 363       John Cena      5    35  20-Sep-15  Night of Champions
#
#                 location                  link  \
# 243       Greenville, SC       /wiki/Ric_Flair
# 256        Charlotte, NC  /wiki/Wahoo_McDaniel
# 282    Daytona Beach, FL       /wiki/Ric_Flair
# 292       Rapid City, SD       /wiki/Lex_Luger
# 339     Jacksonville, FL    /wiki/Chris_Benoit
# 346  Toronto, ON, Canada       /wiki/Bret_Hart
# 363          Houston, TX       /wiki/John_Cena
#
#                                belt date_of_birth date_of_death  \
# ...

# %% [markdown]
# ## Chris benoit, Lex luger, Ric flair, Bret hart and wahoo mcdaniel has won the wwe united states championship 5 times

# %%
r.iloc[np.where(r['belt']=="WWE Women's Championship")]
# Out:
#                     name  reign  days       date         event  \
# 149  The Fabulous Moolah      5  2113  10-Oct-78    Live event
# 187        Trish Stratus      5   176  13-Jun-04     Bad Blood
# 204         Mickie James      5    23  31-Jan-10  Royal Rumble
#
#            location                       link                      belt  \
# 149  Fort Worth, TX  /wiki/The_Fabulous_Moolah  WWE Women's Championship
# 187    Columbus, OH        /wiki/Trish_Stratus  WWE Women's Championship
# 204     Atlanta, GA         /wiki/Mickie_James  WWE Women's Championship
#
#     date_of_birth date_of_death cause_of_death
# 149     7/22/1923     11/2/2007            NaN
# 187    12/18/1975           NaN            NaN
# 204     8/31/1979           NaN            NaN

# %% [markdown]
# ## These 3 women has won the WWE Women's Championship 5 times

# %%
r.iloc[np.where(r['belt']=="WWE SmackDown Women's Championship")]
# Out:
#                 name  reign  days      date           event        location  \
# 410  Charlotte Flair      5     5  6-Oct-19  Hell in a Cell  Sacramento, CA
#
#                       link                                belt date_of_birth  \
# 410  /wiki/Charlotte_Flair  WWE SmackDown Women's Championship      4/5/1986
#
#     date_of_death cause_of_death
# 410           NaN            NaN

# %% [markdown]
# ## Charlotte flair has won the WWE Raw Women's Championship 5 times
# ### She is the daughter of Ric flair

# %%
d=wwe[wwe['reign']==4]
d
# Out:
#                         name  reign  days       date  \
# 20                Hulk Hogan      4     1   3-Dec-91
# 35                 Bret Hart      4     1  16-Feb-97
# 50   Stone Cold Steve Austin      4    55  28-Jun-99
# 57                  The Rock      4    21  30-Apr-00
# 58                  Triple H      4    35  21-May-00
# 68            The Undertaker      4    63  19-May-02
# 74                Kurt Angle      4    51  27-Jul-03
# 90                      Edge      4    21  25-Jan-09
# 94               Randy Orton      4    90  15-Jun-09
# 95                 John Cena      4    21  13-Sep-09
# 122             Brock Lesnar      4   224  17-Aug-14
# 137             Daniel Bryan      4   145  13-Nov-18
# 147      The Fabulous Moolah      4  1226  31-May-75
# 167      The Fabulous Moolah      4     8  17-Oct-99
# 182            Trish Stratus      4    28  30-Mar-03
# 193                     Lita      4    21   5-Nov-06
# 200             Mickie James      4   125  14-Apr-08
# ...

# %%
d.iloc[np.where((d['belt']=='WWE Championship')&(d['name']!="John Cena")&(d['name']!="Randy Orton"))]
# Out:
#                         name  reign  days       date  \
# 20                Hulk Hogan      4     1   3-Dec-91
# 35                 Bret Hart      4     1  16-Feb-97
# 50   Stone Cold Steve Austin      4    55  28-Jun-99
# 57                  The Rock      4    21  30-Apr-00
# 58                  Triple H      4    35  21-May-00
# 68            The Undertaker      4    63  19-May-02
# 74                Kurt Angle      4    51  27-Jul-03
# 90                      Edge      4    21  25-Jan-09
# 122             Brock Lesnar      4   224  17-Aug-14
# 137             Daniel Bryan      4   145  13-Nov-18
#
#                             event          location  \
# 20          This Tuesday in Texas   San Antonio, TX
# 35   In Your House 13: Final Four   Chattanooga, TN
# 50                            Raw     Charlotte, NC
# 57                       Backlash  Washington, D.C.
# 58                   Judgment Day    Louisville, KY
# 68                   Judgment Day     Nashville, TN
# ...

# %% [markdown]
# ## Kurt angle,The undertaker, Edge, Daniel bryan has won the WWE Championship 4 times

# %%
d.iloc[np.where((d['belt']=='WWE United States Championship')&(d['name']!="John Cena"))]
# Out:
#                 name  reign  days       date                          event  \
# 241        Ric Flair      4    98  19-Apr-80                     House show
# 255   Wahoo McDaniel      4     7  24-Jun-84                     House show
# 268        Lex Luger      4   210  16-Dec-90                      Starrcade
# 274  Ricky Steamboat      4    25  24-Aug-94  Clash of the Champions XXVIII
# 303        Bret Hart      4    14  25-Oct-99                          Nitro
# 333         Booker T      4    40  10-Jan-06                     SmackDown!
# 334     Chris Benoit      4    42  19-Feb-06                     No Way Out
#
#              location                       link  \
# 241    Greensboro, NC            /wiki/Ric_Flair
# 255    Greensboro, NC       /wiki/Wahoo_McDaniel
# 268     St. Louis, MO            /wiki/Lex_Luger
# 274  Cedar Rapids, IA      /wiki/Ricky_Steamboat
# 303       Phoenix, AZ            /wiki/Bret_Hart
# 333  Philadelphia, PA  /wiki/Booker_T_(wrestler)
# ...

# %% [markdown]
# ## Booker T and Ricky steamboat has won the WWE United States Championship 4 times

# %%
d.iloc[np.where(d['belt']=="WWE Women's Championship")]
# Out:
#                     name  reign  days       date             event  \
# 147  The Fabulous Moolah      4  1226  31-May-75        Live event
# 167  The Fabulous Moolah      4     8  17-Oct-99          No Mercy
# 182        Trish Stratus      4    28  30-Mar-03  WrestleMania XIX
# 193                 Lita      4    21   5-Nov-06      Cyber Sunday
# 200         Mickie James      4   125  14-Apr-08               Raw
#
#             location                       link                      belt  \
# 147       Dallas, TX  /wiki/The_Fabulous_Moolah  WWE Women's Championship
# 167    Cleveland, OH  /wiki/The_Fabulous_Moolah  WWE Women's Championship
# 182      Seattle, WA        /wiki/Trish_Stratus  WWE Women's Championship
# 193   Cincinnati, OH      /wiki/Lita_(wrestler)  WWE Women's Championship
# 200  London, England         /wiki/Mickie_James  WWE Women's Championship
#
#     date_of_birth date_of_death cause_of_death
# 147     7/22/1923     11/2/2007            NaN
# ...

# %% [markdown]
# ## Lita has won the WWE Women's Championship 4 times

# %%
d.iloc[np.where(d['belt']=="WWE Raw Women's Championship")]
# Out:
#                 name  reign  days       date                       event  \
# 214  Charlotte Flair      4    57  18-Dec-16  Roadblock: End of the Line
# 217      Sasha Banks      4     8  20-Aug-17                  SummerSlam
#
#            location                   link                          belt  \
# 214  Pittsburgh, PA  /wiki/Charlotte_Flair  WWE Raw Women's Championship
# 217    Brooklyn, NY      /wiki/Sasha_Banks  WWE Raw Women's Championship
#
#     date_of_birth date_of_death cause_of_death
# 214      4/5/1986           NaN            NaN
# 217     1/26/1992           NaN            NaN

# %% [markdown]
# ## Sasha banks won WWE Raw Women's Championship 4 times

# %%
d.iloc[np.where(d['belt']=="WWE SmackDown Women's Championship")]
# Out:
#                 name  reign  days       date              event      location  \
# 408  Charlotte Flair      4     0  19-May-19  Money in the Bank  Hartford, CT
#
#                       link                                belt date_of_birth  \
# 408  /wiki/Charlotte_Flair  WWE SmackDown Women's Championship      4/5/1986
#
#     date_of_death cause_of_death
# 408           NaN            NaN

# %%
h=wwe[wwe['reign']==3]
h
# Out:
#                         name  reign  days                  date  \
# 18                Hulk Hogan      3   248             24-Mar-91
# 31                 Bret Hart      3   133             19-Nov-95
# 39            Shawn Michaels      3   140              9-Nov-97
# 47                  The Rock      3    41             15-Feb-99
# 48   Stone Cold Steve Austin      3    56             28-Mar-99
# 49            The Undertaker      3    36             23-May-99
# 51                   Mankind      3     1             22-Aug-99
# 56                  Triple H      3   118              3-Jan-00
# 72                Kurt Angle      3   105             15-Dec-02
# 75              Brock Lesnar      3   152             16-Sep-03
# 83                 John Cena      3   380             17-Sep-06
# 88                      Edge      3    21             23-Nov-08
# 92               Randy Orton      3    42             26-Apr-09
# 120             Daniel Bryan      3    64              6-Apr-14
# ...

# %%
h.iloc[np.where(h['belt']=="WWE Championship")]
# Out:
#                         name  reign  days       date             event  \
# 18                Hulk Hogan      3   248  24-Mar-91  WrestleMania VII
# 31                 Bret Hart      3   133  19-Nov-95   Survivor Series
# 39            Shawn Michaels      3   140   9-Nov-97   Survivor Series
# 47                  The Rock      3    41  15-Feb-99               Raw
# 48   Stone Cold Steve Austin      3    56  28-Mar-99   WrestleMania XV
# 49            The Undertaker      3    36  23-May-99     Over the Edge
# 51                   Mankind      3     1  22-Aug-99        SummerSlam
# 56                  Triple H      3   118   3-Jan-00               Raw
# 72                Kurt Angle      3   105  15-Dec-02        Armageddon
# 75              Brock Lesnar      3   152  16-Sep-03        SmackDown!
# 83                 John Cena      3   380  17-Sep-06        Unforgiven
# 88                      Edge      3    21  23-Nov-08   Survivor Series
# ...

# %% [markdown]
# ## Sheamus,Roman reigns, Shawn michaels and The mankind has won the WWE Championship 3 times

# %%
h.iloc[np.where(h['belt']=='WWE United States Championship')]
# Out:
#                    name  reign  days       date          event  \
# 230          Paul Jones      3     6   9-Dec-76     House show
# 235  Blackjack Mulligan      3    77   1-Jan-78     House show
# 239           Ric Flair      3   133   1-Apr-79     House show
# 249      Wahoo McDaniel      3    74  22-Aug-82     House show
# 254     Ricky Steamboat      3    64  21-Apr-84     House show
# 266           Lex Luger      3   523  22-May-89     House show
# 295           Bret Hart      3    70  30-Nov-98          Nitro
# 296         Roddy Piper      3    13   8-Feb-99          Nitro
# 307        Jeff Jarrett      3    84  17-Jan-00          Nitro
# 313         Lance Storm      3    16  10-Nov-00          Nitro
# 329           John Cena      3   105  16-Nov-04     SmackDown!
# 331        Chris Benoit      3    58  21-Aug-05     SummerSlam
# 332            Booker T      3    35  18-Oct-05     SmackDown!
# 357       Kofi Kingston      3    34  15-Apr-13            Raw
# ...

# %% [markdown]
# ## Aj styles, Rusev, Kevin owens, Kofi kingston Lance storm, jeff jarret, roddy piper, Blackjack mulligan has won WWE United States Championship 3 times

# %%
h.iloc[np.where(h['belt']=="WWE Women's Championship")]
# Out:
#                     name  reign  days                  date          event  \
# 145  The Fabulous Moolah      3  2862              2-Apr-68     Live event
# 155  The Fabulous Moolah      3   380              9-Jul-86     Live event
# 162       Alundra Blayze      3    51             23-Oct-95            Raw
# 174                Ivory      3   152  October 31, 2000[30]     SmackDown!
# 180        Trish Stratus      3    56             22-Sep-02     Unforgiven
# 191                 Lita      3    34             14-Aug-06            Raw
# 196         Mickie James      3     0             24-Apr-07     Live event
# 202               Melina      3   154             25-Jan-09   Royal Rumble
# 206         Beth Phoenix      3    16             25-Apr-10  Extreme Rules
#
#                 location                       link                      belt  \
# 145     Hamamatsu, Japan  /wiki/The_Fabulous_Moolah  WWE Women's Championship
# ...

# %% [markdown]
# ## Beth phoenix, Melina, Ivory, Alundra blayze have won "WWE Women's Championship" 3 times

# %%
h.iloc[np.where(h['belt']=="WWE Raw Women's Championship")]
# Out:
#                 name  reign  days       date              event  \
# 212  Charlotte Flair      3    29  30-Oct-16     Hell in a Cell
# 213      Sasha Banks      3    20  28-Nov-16                Raw
# 220      Alexa Bliss      3    63  17-Jun-18  Money in the Bank
#
#           location                   link                          belt  \
# 212     Boston, MA  /wiki/Charlotte_Flair  WWE Raw Women's Championship
# 213  Charlotte, NC      /wiki/Sasha_Banks  WWE Raw Women's Championship
# 220   Rosemont, IL      /wiki/Alexa_Bliss  WWE Raw Women's Championship
#
#     date_of_birth date_of_death cause_of_death
# 212      4/5/1986           NaN            NaN
# 213     1/26/1992           NaN            NaN
# 220      8/9/1991           NaN            NaN

# %% [markdown]
# ## Alexa bliss has won WWE Raw Women's Championship 3 times

# %%
h.iloc[np.where(h['belt']=="WWE SmackDown Women's Championship")]
# Out:
#                 name  reign  days       date            event  \
# 406  Charlotte Flair      3    13  26-Mar-19        SmackDown
# 407      Becky Lynch      3    41   8-Apr-19  WrestleMania 35
#
#                 location                   link  \
# 406       Uncasville, CT  /wiki/Charlotte_Flair
# 407  East Rutherford, NJ      /wiki/Becky_Lynch
#
#                                    belt date_of_birth date_of_death  \
# 406  WWE SmackDown Women's Championship      4/5/1986           NaN
# 407  WWE SmackDown Women's Championship     1/30/1987           NaN
#
#     cause_of_death
# 406            NaN
# 407            NaN

# %% [markdown]
# ## Becky lynch has won the WWE SmackDown Women's Championship 3 times

# %%
p=wwe[wwe['reign']==2]
p
# Out:
#                  name  reign  days       date                 event  \
# 5    Bruno Sammartino      2  1237  10-Dec-73            House show
# 9        Bob Backlund      2  1470  17-Dec-79    WWF on MSG Network
# 15         Hulk Hogan      2   364   2-Apr-89        WrestleMania V
# 22       Randy Savage      2   149   5-Apr-92     WrestleMania VIII
# 23          Ric Flair      2    41   1-Sep-92  Prime Time Wrestling
# ..                ...    ...   ...        ...                   ...
# 398       Alexa Bliss      2    40  21-Feb-17             SmackDown
# 399             Naomi      2   140   2-Apr-17       WrestleMania 33
# 403   Charlotte Flair      2    28  19-Aug-18            SummerSlam
# 404       Becky Lynch      2    91  16-Sep-18        Hell in a Cell
# 411            Bayley      2   247  11-Oct-19             SmackDown
#
#               location                     link  \
# 5         New York, NY   /wiki/Bruno_Sammartino
# 9         New York, NY       /wiki/Bob_Backlund
# ...

# %%
p.iloc[np.where(p['belt']=="WWE Championship")]
# Out:
#                         name  reign  days       date                 event  \
# 5           Bruno Sammartino      2  1237  10-Dec-73            House show
# 9               Bob Backlund      2  1470  17-Dec-79    WWF on MSG Network
# 15                Hulk Hogan      2   364   2-Apr-89        WrestleMania V
# 22              Randy Savage      2   149   5-Apr-92     WrestleMania VIII
# 23                 Ric Flair      2    41   1-Sep-92  Prime Time Wrestling
# 27                  Yokozuna      2   280  13-Jun-93      King of the Ring
# 28                 Bret Hart      2   248  20-Mar-94        WrestleMania X
# 29              Bob Backlund      2     3  23-Nov-94       Survivor Series
# 34            Shawn Michaels      2    25  19-Jan-97          Royal Rumble
# 36                 Sycho Sid      2    34  17-Feb-97                   Raw
# 37            The Undertaker      2   133  23-Mar-97       WrestleMania 13
# ...

# %% [markdown]
# ## Bruno samarttino, Bob backlund, Randy savage, Yokozuna, Big show, Batista, Cm punk, Seth rollins, Aj styles, Daniel Bryan, Alberto delrio, and sycho sid has won the WWE Championship 2 times

# %%
p.iloc[np.where(p['belt']=="WWE United States Championship")]
# Out:
#                          name  reign  days       date  \
# 228                Paul Jones      2    43  16-Oct-76
# 229        Blackjack Mulligan      2    11  28-Nov-76
# 231        Blackjack Mulligan      2   204  15-Dec-76
# 237                 Ric Flair      2   253   9-Apr-78
# 238           Ricky Steamboat      2   105  17-Dec-78
# 247            Wahoo McDaniel      2    17  21-May-82
# 248            Sgt. Slaughter      2    76   7-Jun-82
# 251               Roddy Piper      2    14  16-Apr-83
# 252            Greg Valentine      2   228  30-Apr-83
# 259               Magnum T.A.      2   182  28-Nov-85
# 264                 Lex Luger      2    76  20-Feb-89
# 272             Dustin Rhodes      2   119  30-Aug-93
# 275              Steve Austin      2     0  18-Sep-94
# 278                     Sting      2   148  18-Jun-95
# 293                 Bret Hart      2    74  13-Aug-98
# 294       Diamond Dallas Page      2    35  26-Oct-98
# ...

# %% [markdown]
# ## Rey mysterio, Samoa joe, R-truth, shinsuke nakamura, Dolph ziggler, Chris jerico, Kalisto, Alberto delrio, The miz, Montel vonatvious porter, Eddie gurrero, Gen rection, Terry funk, Scott steiner, Scott hall, Goldberg, Diamond dallas page, Sting, Steve austin, Dustin rhodes, Magnum T.A, Greg valentine and sgt slaughter has won the wwe United States Championship 2 times

# %%
p.iloc[np.where(p['belt']=="WWE Women's Championship")]
# Out:
#                     name  reign  days                  date            event  \
# 143  The Fabulous Moolah      2   524              3-Oct-66       Live event
# 152        Wendi Richter      2   239             31-Mar-85   WrestleMania I
# 153      The Spider Lady      2   220             25-Nov-85       Live event
# 160       Alundra Blayze      2   146              3-Apr-95              Raw
# 168                Ivory      2    48             25-Oct-99       Raw is War
# 171           Jacqueline      2    56  February 1, 2000[30]       SmackDown!
# 178        Trish Stratus      2    41             13-May-02              Raw
# 183                 Jazz      2    64             27-Apr-03         Backlash
# 185          Molly Holly      2   210             28-Jul-03              Raw
# 186             Victoria      2   111             23-Feb-04              Raw
# 188                 Lita      2    34              6-Dec-04              Raw
# ...

# %% [markdown]
# ## Michelle mcCool, Victoria, Molly holly, Jazz, Jacqulein, The spider lady and wendi richter has won the WWE Women's Championship 2 times

# %%
p.iloc[np.where(p['belt']=="WWE Raw Women's Championship")]
# Out:
#             name  reign  days       date       event         location  \
# 210    Charlotte      2    43  21-Aug-16  SummerSlam     Brooklyn, NY
# 211  Sasha Banks      2    27   3-Oct-16         Raw  Los Angeles, CA
# 218  Alexa Bliss      2   223  28-Aug-17         Raw      Memphis, TN
#
#                       link                          belt date_of_birth  \
# 210  /wiki/Charlotte_Flair  WWE Raw Women's Championship      4/5/1986
# 211      /wiki/Sasha_Banks  WWE Raw Women's Championship     1/26/1992
# 218      /wiki/Alexa_Bliss  WWE Raw Women's Championship      8/9/1991
#
#     date_of_death cause_of_death
# 210           NaN            NaN
# 211           NaN            NaN
# 218           NaN            NaN

# %%
p.iloc[np.where(p['belt']=="WWE SmackDown Women's Championship")]
# Out:
#                 name  reign  days       date            event  \
# 398      Alexa Bliss      2    40  21-Feb-17        SmackDown
# 399            Naomi      2   140   2-Apr-17  WrestleMania 33
# 403  Charlotte Flair      2    28  19-Aug-18       SummerSlam
# 404      Becky Lynch      2    91  16-Sep-18   Hell in a Cell
# 411           Bayley      2   247  11-Oct-19        SmackDown
#
#             location                     link  \
# 398      Ontario, CA        /wiki/Alexa_Bliss
# 399      Orlando, FL   /wiki/Naomi_(wrestler)
# 403     Brooklyn, NY    /wiki/Charlotte_Flair
# 404  San Antonio, TX        /wiki/Becky_Lynch
# 411     Paradise, NV  /wiki/Bayley_(wrestler)
#
#                                    belt date_of_birth date_of_death  \
# 398  WWE SmackDown Women's Championship      8/9/1991           NaN
# 399  WWE SmackDown Women's Championship    11/30/1987           NaN
# 403  WWE SmackDown Women's Championship      4/5/1986           NaN
# ...

# %% [markdown]
# ## Bayley, Naomi, Alexa bliss has won the WWE SmackDown Championship 2 times

# %%
o=wwe[wwe['reign']==1]
o
# Out:
#                  name  reign  days       date                          event  \
# 0        Buddy Rogers      1    36  11-Apr-63                     House show
# 1    Bruno Sammartino      1  2803  17-May-63                     House show
# 2         Ivan Koloff      1    21  18-Jan-71                     House show
# 3       Pedro Morales      1  1027   8-Feb-71                     House show
# 4        Stan Stasiak      1     9   1-Dec-73                     House show
# ..                ...    ...   ...        ...                            ...
# 400           Natalya      1    86  20-Aug-17                     SummerSlam
# 401   Charlotte Flair      1   147  14-Nov-17                      SmackDown
# 402          Carmella      1   131  10-Apr-18                      SmackDown
# 405             Asuka      1   100  16-Dec-18  TLC: Tables, Ladders & Chairs
# 409            Bayley      1   140  19-May-19              Money in the Bank
#
# ...

# %%
o.iloc[np.where(o['belt']=="WWE Championship")]
# Out:
#                         name  reign  days                  date  \
# 0               Buddy Rogers      1    36             11-Apr-63
# 1           Bruno Sammartino      1  2803             17-May-63
# 2                Ivan Koloff      1    21             18-Jan-71
# 3              Pedro Morales      1  1027              8-Feb-71
# 4               Stan Stasiak      1     9              1-Dec-73
# 6     Superstar Billy Graham      1   296             30-Apr-77
# 7               Bob Backlund      1   648             20-Feb-78
# 8              Antonio Inoki      1     6             30-Nov-79
# 10            The Iron Sheik      1    28             26-Dec-83
# 11                Hulk Hogan      1  1474             23-Jan-84
# 12           André the Giant      1     0              5-Feb-88
# 13               Ted DiBiase      1     8              5-Feb-88
# 14              Randy Savage      1   371             27-Mar-88
# 16      The Ultimate Warrior      1   293              1-Apr-90
# ...

# %% [markdown]
# ## Drew mcIntyre, Jinder mahal, Bray wyatt, Dean Ambrose, Rey mysterio, Jeff Hardy, Rob van dam, John Bradshaw Layfield(JBL),Eddie Gurrero, Vince Mcmahon, Kane, Diesel, the ultimate warrior, Ted diBiase, Andre the giant, The iron shiek, Antonio inoki,Superstar billy Graham,Stan stasiak,Pedro morales,Ivan koloff and Buddy rogers has won the WWE Championship only 1 time

# %%
o.iloc[np.where(o['belt']=="WWE United States Championship")]
# Out:
#                    name  reign  days       date              event  \
# 223         Harley Race      1   183   1-Jan-75         House show
# 224    Johnny Valentine      1    93   3-Jul-75         House show
# 225          Terry Funk      1    18   9-Nov-75         House show
# 226          Paul Jones      1   107  27-Nov-75         House show
# 227  Blackjack Mulligan      1   217  13-Mar-76         House show
# ..                  ...    ...   ...        ...                ...
# 387           Samoa Joe      1    75   5-Mar-19          SmackDown
# 388        Rey Mysterio      1    15  19-May-19  Money in the Bank
# 390            Ricochet      1    21  23-Jun-19   Stomping Grounds
# 393             Andrade      1   151  26-Dec-19           WWE Live
# 394        Apollo Crews      1    20  25-May-20                Raw
#
#              location                         link  \
# 223   Tallahassee, FL            /wiki/Harley_Race
# 224    Greensboro, NC       /wiki/Johnny_Valentine
# ...

# %% [markdown]
# ## These all non repeating names in this list has won the WWE United States Championship only 1 time

# %%
o.iloc[np.where(o['belt']=="WWE Women's Championship")]
# Out:
#                            name  reign  days                    date  \
# 141         The Fabulous Moolah      1  3651               18-Sep-56
# 142               Bette Boucher      1    13               17-Sep-66
# 144                Yukiko Tomoe      1    23               10-Mar-68
# 146                   Sue Green      1     2               29-May-75
# 148              Evelyn Stevens      1     2                8-Oct-78
# 150               Wendi Richter      1   210               23-Jul-84
# 151                 Leilani Kai      1    41               18-Feb-85
# 154             Velvet McIntyre      1     6                3-Jul-86
# 156          Sensational Sherri      1   441               24-Jul-87
# 157               Rockin' Robin      1   502                7-Oct-88
# 158              Alundra Blayze      1   342               13-Dec-93
# 159                 Bull Nakano      1   134               20-Nov-94
# 161                 Bertha Faye      1    57               27-Aug-95
# ...

# %% [markdown]
# ## These all non repeating names in this list has won the WWE Women's Championship only 1 time

# %%
o.iloc[np.where(o['belt']=="WWE Raw Women's Championship")]
# Out:
#              name  reign  days       date            event  \
# 208     Charlotte      1   113   3-Apr-16  WrestleMania 32
# 209   Sasha Banks      1    27  25-Jul-16              Raw
# 215        Bayley      1    76  13-Feb-17              Raw
# 216   Alexa Bliss      1   112  30-Apr-17          Payback
# 219       Nia Jax      1    70   8-Apr-18  WrestleMania 34
# 221  Ronda Rousey      1   232  19-Aug-18       SummerSlam
# 222   Becky Lynch      1   373   8-Apr-19  WrestleMania 35
#
#                 location                     link  \
# 208        Arlington, TX    /wiki/Charlotte_Flair
# 209       Pittsburgh, PA        /wiki/Sasha_Banks
# 215        Las Vegas, NV  /wiki/Bayley_(wrestler)
# 216         San Jose, CA        /wiki/Alexa_Bliss
# 219      New Orleans, LA            /wiki/Nia_Jax
# 221         Brooklyn, NY       /wiki/Ronda_Rousey
# 222  East Rutherford, NJ        /wiki/Becky_Lynch
#
#                              belt date_of_birth date_of_death cause_of_death
# ...

# %% [markdown]
# ## Bayley, Nia jax, Ronda rousey,Bayley has won the WWE Raw women's Championship only 1 time

# %%
o.iloc[np.where(o['belt']=="WWE SmackDown Women's Championship")]
# Out:
#                 name  reign  days       date                          event  \
# 395      Becky Lynch      1    84  11-Sep-16                       Backlash
# 396      Alexa Bliss      1    70   4-Dec-16  TLC: Tables, Ladders & Chairs
# 397            Naomi      1     9  12-Feb-17            Elimination Chamber
# 400          Natalya      1    86  20-Aug-17                     SummerSlam
# 401  Charlotte Flair      1   147  14-Nov-17                      SmackDown
# 402         Carmella      1   131  10-Apr-18                      SmackDown
# 405            Asuka      1   100  16-Dec-18  TLC: Tables, Ladders & Chairs
# 409           Bayley      1   140  19-May-19              Money in the Bank
#
#             location                       link  \
# 395     Richmond, VA          /wiki/Becky_Lynch
# 396       Dallas, TX          /wiki/Alexa_Bliss
# 397      Phoenix, AZ     /wiki/Naomi_(wrestler)
# 400     Brooklyn, NY     /wiki/Natalya_Neidhart
# ...

# %% [markdown]
# ## Natalya,Carmella and Asuka has won the WWE SmackDown Women's Championship 1 time

# %%
wwe['belt'].unique()
# Out:
# array(['WWE Championship', "WWE Women's Championship",
#        "WWE Raw Women's Championship", 'WWE United States Championship',
#        "WWE SmackDown Women's Championship"], dtype=object)

# %%
wwe['event'].unique()  #these all are the events organized by WWE Network
# Out:
# array(['House show', 'WWF on MSG Network', 'The Main Event I',
#        'WrestleMania IV', 'WrestleMania V', 'WrestleMania VI',
#        'Royal Rumble', 'WrestleMania VII', 'Survivor Series',
#        'This Tuesday in Texas', 'WrestleMania VIII',
#        'Prime Time Wrestling', 'WrestleMania IX', 'King of the Ring',
#        'WrestleMania X', 'WrestleMania XII',
#        'In Your House 13: Final Four', 'Raw', 'WrestleMania 13',
#        'SummerSlam', 'WrestleMania XIV', 'Halftime Heat',
#        'WrestleMania XV', 'Over the Edge', 'SmackDown!', 'Unforgiven',
#        'Backlash', 'Judgment Day', 'No Mercy', 'No Way Out',
#        'WrestleMania X-Seven', 'Vengeance', 'WrestleMania X8',
#        'Armageddon', 'WrestleMania XIX', 'The Great American Bash',
#        'WrestleMania 21', "New Year's Revolution", 'ECW One Night Stand',
#        'Extreme Rules', 'Breaking Point', 'Hell in a Cell',
#        'Bragging Rights', 'TLC: Tables, Ladders & Chairs',
# ...

# %% [markdown]
# ## RAW and SmackDown are fixed show by WWE network on Monday and Friday night, these usually known as monday night Raw and Friday night SmackDown

# %% [markdown]
# # WrestleMania is the biggest Pay Per View of WWE network it usually oragnized in the month of april

# %% [markdown]
# ## Royal Rumble, TLC, Summer Slam, Survivor Series, Elimination Chamber, Money in the bank, Exterme Rules are the fixed Pay Per View of WWE network

# %%
wwe['date_of_death']=wwe['date_of_death'].fillna("Not Avialable")

# %%
wwe.iloc[np.where(wwe['date_of_death'] != "Not Avialable" )]
# Out:
#                      name  reign  days       date  \
# 0            Buddy Rogers      1    36  11-Apr-63
# 1        Bruno Sammartino      1  2803  17-May-63
# 2             Ivan Koloff      1    21  18-Jan-71
# 3           Pedro Morales      1  1027   8-Feb-71
# 4            Stan Stasiak      1     9   1-Dec-73
# 5        Bruno Sammartino      2  1237  10-Dec-73
# 12        André the Giant      1     0   5-Feb-88
# 14           Randy Savage      1   371  27-Mar-88
# 16   The Ultimate Warrior      1   293   1-Apr-90
# 22           Randy Savage      2   149   5-Apr-92
# 25               Yokozuna      1     0   4-Apr-93
# 27               Yokozuna      2   280  13-Jun-93
# 76         Eddie Guerrero      1   133  15-Feb-04
# 141   The Fabulous Moolah      1  3651  18-Sep-56
# 143   The Fabulous Moolah      2   524   3-Oct-66
# 145   The Fabulous Moolah      3  2862   2-Apr-68
# 147   The Fabulous Moolah      4  1226  31-May-75
# 149   The Fabulous Moolah      5  2113  10-Oct-78
# ...

# %% [markdown]
# ## These are the Wrestlers who passed away

# %%
v=wwe.iloc[np.where(wwe['belt']=='WWE Championship')]
v
# Out:
#                  name  reign  days                  date  \
# 0        Buddy Rogers      1    36             11-Apr-63
# 1    Bruno Sammartino      1  2803             17-May-63
# 2         Ivan Koloff      1    21             18-Jan-71
# 3       Pedro Morales      1  1027              8-Feb-71
# 4        Stan Stasiak      1     9              1-Dec-73
# ..                ...    ...   ...                   ...
# 136         AJ Styles      2   371              7-Nov-17
# 137      Daniel Bryan      4   145             13-Nov-18
# 138     Kofi Kingston      1   180              7-Apr-19
# 139      Brock Lesnar      5   173              4-Oct-19
# 140     Drew McIntyre      1    71  March 25 or 26, 2020
#
#                            event             location  \
# 0                     House show     Washington, D.C.
# 1                     House show         New York, NY
# 2                     House show         New York, NY
# 3                     House show         New York, NY
# ...

# %%
b=v.groupby(['name'])['days'].max()
b.sort_values(ascending=False)
# Out:
# name
# Bruno Sammartino           2803
# Hulk Hogan                 1474
# Bob Backlund               1470
# Pedro Morales              1027
# CM Punk                     434
# John Cena                   380
# AJ Styles                   371
# Randy Savage                371
# Diesel                      358
# Superstar Billy Graham      296
# The Ultimate Warrior        293
# John Bradshaw Layfield      280
# Yokozuna                    280
# Bret Hart                   248
# Shawn Michaels              231
# Brock Lesnar                224
# Seth Rollins                220
# Triple H                    210
# Randy Orton                 203
# Kofi Kingston               180
# Stone Cold Steve Austin     175
# Jinder Mahal                170
# The Miz                     160
# Daniel Bryan                145
# The Undertaker              133
# Eddie Guerrero              133
# Kurt Angle                  126
# The Rock                    119
# Chris Jericho                98
# ...

# %% [markdown]
# ## Bruno Sammartino has hold the WWE Championship with 2803 day which is maximum

# %%
w=wwe.iloc[np.where(wwe['belt']=='WWE United States Championship')]
w
# Out:
#                    name  reign  days       date             event  \
# 223         Harley Race      1   183   1-Jan-75        House show
# 224    Johnny Valentine      1    93   3-Jul-75        House show
# 225          Terry Funk      1    18   9-Nov-75        House show
# 226          Paul Jones      1   107  27-Nov-75        House show
# 227  Blackjack Mulligan      1   217  13-Mar-76        House show
# ..                  ...    ...   ...        ...               ...
# 390            Ricochet      1    21  23-Jun-19  Stomping Grounds
# 391           AJ Styles      3   134  14-Jul-19     Extreme Rules
# 392        Rey Mysterio      2    31  25-Nov-19               Raw
# 393             Andrade      1   151  26-Dec-19          WWE Live
# 394        Apollo Crews      1    20  25-May-20               Raw
#
#              location                         link  \
# 223   Tallahassee, FL            /wiki/Harley_Race
# 224    Greensboro, NC       /wiki/Johnny_Valentine
# ...

# %%
c=w.groupby(['name'])['days'].max()
c.sort_values(ascending=False)
# Out:
# name
# Lex Luger                   523
# Rick Rude                   378
# Dean Ambrose                351
# Montel Vontavious Porter    343
# Nikita Koloff               328
#                            ...
# Michael Hayes                15
# Tajiri                       13
# Jinder Mahal                  8
# Edge                          6
# Raven                         1
# Name: days, Length: 97, dtype: int64

# %% [markdown]
# ## Lex Luger has hold the WWE United States Championship title 523 which is maximum

# %%
g=wwe.iloc[np.where(wwe['belt']=="WWE Women's Championship")]
g
# Out:
#                     name  reign  days       date          event  \
# 141  The Fabulous Moolah      1  3651  18-Sep-56     Live event
# 142        Bette Boucher      1    13  17-Sep-66     Live event
# 143  The Fabulous Moolah      2   524   3-Oct-66     Live event
# 144         Yukiko Tomoe      1    23  10-Mar-68     Live event
# 145  The Fabulous Moolah      3  2862   2-Apr-68     Live event
# ..                   ...    ...   ...        ...            ...
# 203      Michelle McCool      1   217  28-Jun-09       The Bash
# 204         Mickie James      5    23  31-Jan-10   Royal Rumble
# 205      Michelle McCool      2    61  23-Feb-10      SmackDown
# 206         Beth Phoenix      3    16  25-Apr-10  Extreme Rules
# 207                Layla      1   131  11-May-10      SmackDown
#
#              location                       link                      belt  \
# 141     Baltimore, MD  /wiki/The_Fabulous_Moolah  WWE Women's Championship
# ...

# %%
n=g.groupby(['name'])['days'].max()
n.sort_values(ascending=False)
# Out:
# name
# The Fabulous Moolah           3651
# Rockin' Robin                  502
# Trish Stratus                  448
# Sensational Sherri             441
# Alundra Blayze                 342
# Wendi Richter                  239
# The Spider Lady                220
# Michelle McCool                217
# Chyna                          214
# Molly Holly                    210
# Beth Phoenix                   190
# Sable                          176
# Melina                         154
# Ivory                          152
# Stephanie McMahon-Helmsley     146
# Mickie James                   134
# Bull Nakano                    134
# Victoria                       133
# Layla                          131
# Candice Michelle               105
# Jazz                            98
# Lita                            71
# Jacqueline                      61
# Bertha Faye                     57
# The Kat                         50
# Leilani Kai                     41
# ...

# %% [markdown]
# ## The Fabulous Moolah has hold the WWE Women's Championship 3651 days which is maximum

# %%
y=wwe.iloc[np.where(wwe['belt']=="WWE Raw Women's Championship")]
y
# Out:
#                 name  reign  days       date                       event  \
# 208        Charlotte      1   113   3-Apr-16             WrestleMania 32
# 209      Sasha Banks      1    27  25-Jul-16                         Raw
# 210        Charlotte      2    43  21-Aug-16                  SummerSlam
# 211      Sasha Banks      2    27   3-Oct-16                         Raw
# 212  Charlotte Flair      3    29  30-Oct-16              Hell in a Cell
# 213      Sasha Banks      3    20  28-Nov-16                         Raw
# 214  Charlotte Flair      4    57  18-Dec-16  Roadblock: End of the Line
# 215           Bayley      1    76  13-Feb-17                         Raw
# 216      Alexa Bliss      1   112  30-Apr-17                     Payback
# 217      Sasha Banks      4     8  20-Aug-17                  SummerSlam
# 218      Alexa Bliss      2   223  28-Aug-17                         Raw
# 219          Nia Jax      1    70   8-Apr-18             WrestleMania 34
# ...

# %%
l=y.groupby(['name'])['days'].max()
l.sort_values(ascending=False)
# Out:
# name
# Becky Lynch        373
# Ronda Rousey       232
# Alexa Bliss        223
# Charlotte          113
# Bayley              76
# Nia Jax             70
# Charlotte Flair     57
# Sasha Banks         27
# Name: days, dtype: int64

# %% [markdown]
# ## Becky Lynch has hold the WWE Raw Women's Championship 373 days which is maximum

# %%
z=wwe.iloc[np.where(wwe['belt']=="WWE SmackDown Women's Championship")]
z
# Out:
#                 name  reign  days       date                          event  \
# 395      Becky Lynch      1    84  11-Sep-16                       Backlash
# 396      Alexa Bliss      1    70   4-Dec-16  TLC: Tables, Ladders & Chairs
# 397            Naomi      1     9  12-Feb-17            Elimination Chamber
# 398      Alexa Bliss      2    40  21-Feb-17                      SmackDown
# 399            Naomi      2   140   2-Apr-17                WrestleMania 33
# 400          Natalya      1    86  20-Aug-17                     SummerSlam
# 401  Charlotte Flair      1   147  14-Nov-17                      SmackDown
# 402         Carmella      1   131  10-Apr-18                      SmackDown
# 403  Charlotte Flair      2    28  19-Aug-18                     SummerSlam
# 404      Becky Lynch      2    91  16-Sep-18                 Hell in a Cell
# 405            Asuka      1   100  16-Dec-18  TLC: Tables, Ladders & Chairs
# ...

# %%
j=z.groupby(['name'])['days'].max()
j.sort_values(ascending=False)
# Out:
# name
# Bayley             247
# Charlotte Flair    147
# Naomi              140
# Carmella           131
# Asuka              100
# Becky Lynch         91
# Natalya             86
# Alexa Bliss         70
# Name: days, dtype: int64

# %% [markdown]
# ## Bayley has hold the WWE SmackDown Women's Championship 247 days which is maximum

# %%
wwe['location'].unique()
# Out:
# array(['Washington, D.C.', 'New York, NY', 'Philadelphia, PA',
#        'Baltimore, MD', 'Tokushima, Japan', 'Indianapolis, IN',
#        'Atlantic City, NJ', 'Toronto, ON, Canada', 'Miami, FL',
#        'Los Angeles, CA', 'Detroit, MI', 'San Antonio, TX', 'Albany, NY',
#        'Hershey, PA', 'Saskatoon, SK, Canada', 'Las Vegas, NV',
#        'Dayton, OH', 'Landover, MD', 'Anaheim, CA', 'Chattanooga, TN',
#        'Nashville, TN', 'Rosemont, IL', 'East Rutherford, NJ',
#        'Montreal, QC, Canada', 'Boston, MA', 'Pittsburgh, PA',
#        'Cleveland, OH', 'St. Louis, MO', 'Worcester, MA', 'Tucson, AZ',
#        'Birmingham, AL', 'Kansas City, MO', 'Charlotte, NC',
#        'Minneapolis, MN', 'Ames, IA', 'Louisville, KY', 'Houston, TX',
#        'San Diego, CA', 'Uniondale, NY', 'Sunrise, FL', 'Seattle, WA',
#        'Denver, CO', 'Raleigh, NC', 'Daly City, CA', 'Norfolk, VA',
#        'Buffalo, NY', 'Providence, RI', 'New Orleans, LA', 'Newark, NJ',
# ...

# %% [markdown]
# ## These are the locations of events organized by WWE network

# %%
plt.xticks(rotation=45)
sns.set(rc = {'figure.figsize':(2,2)})
sns.histplot(wwe['belt'])
# Out:
# <AxesSubplot:xlabel='belt', ylabel='Count'>

# %% [markdown]
# ## United states Championship has held by most wrestlers

# %%
plt.xticks(rotation=45)
sns.set(rc = {'figure.figsize':(5,5)})
sns.histplot(wwe['reign'])
# Out:
# <AxesSubplot:xlabel='reign', ylabel='Count'>

# %% [markdown]
# ## Maximum reign of titles are 1 time
